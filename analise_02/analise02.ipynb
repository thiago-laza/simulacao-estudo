# %%
import pandas as pd

# %%
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# %%
df
# Out:
#              Nome  Ano                                           Problema  \
# 0     Estudante 1    6  Thiago é um pequeno comerciante. Ele trabalha ...
# 1     Estudante 2    9  Thiago é um pequeno comerciante. Ele trabalha ...
# 2     Estudante 3    8  Thiago é um pequeno comerciante. Ele trabalha ...
# 3     Estudante 4    6  Thiago é um pequeno comerciante. Ele trabalha ...
# 4     Estudante 5    7  Thiago é um pequeno comerciante. Ele trabalha ...
# ..            ...  ...                                                ...
# 95   Estudante 96    6  Thiago é um pequeno comerciante. Ele trabalha ...
# 96   Estudante 97    6  Thiago é um pequeno comerciante. Ele trabalha ...
# 97   Estudante 98    7  Thiago é um pequeno comerciante. Ele trabalha ...
# 98   Estudante 99    6  Thiago é um pequeno comerciante. Ele trabalha ...
# 99  Estudante 100    9  Thiago é um pequeno comerciante. Ele trabalha ...
#
#                                         Interpretação  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome             100 non-null    object
#  1   Ano              100 non-null    int64
#  2   Problema         100 non-null    object
#  3   Interpretação    100 non-null    object
#  4   Estratégia       100 non-null    object
#  5   Cálculo/Técnica  100 non-null    object
#  6   Resposta         100 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.6+ KB

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Agrupamento K-Means - Metodo do cotovelo

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ### Interpretacao

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Coluna para agrupamento
textos = df['Interpretação'].tolist()

def tokenizar_texto(texto):
    # Remover pontuação e caracteres especiais
    texto = re.sub(r'[^\w\s]', '', texto)
    # Converter para minúsculas
    texto = texto.lower()
    # Tokenização manual
    tokens = texto.split()
    return tokens

# Tokenizar os textos
textos_tokenizados = [tokenizar_texto(texto) for texto in textos]

# Converter tokens de volta para strings
textos_strings = [" ".join(tokens) for tokens in textos_tokenizados]

# Vetorização TF-IDF
vetorizador = TfidfVectorizer()
vetores_tfidf = vetorizador.fit_transform(textos_strings)

# Método do Cotovelo para encontrar o número ideal de clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(vetores_tfidf)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)

# Supondo que seu DataFrame seja chamado 'df'
frequencia_erros = df['Tipo_Erro_Detalhado'].value_counts()
print("Frequência dos Erros:\n", frequencia_erros)

erros_por_cluster = df.groupby('Cluster_ACM_KMeans')['Tipo_Erro_Detalhado'].value_counts()
print("\nErros por Cluster:\n", erros_por_cluster)
plt.show()

# Aplicar o K-Means com o número ideal de clusters (substitua pelo valor encontrado no gráfico)
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(vetores_tfidf)

# Adicionar os clusters ao DataFrame
df['Cluster_Interpretacao'] = clusters

# Exibir os primeiros 10 registros com os clusters
print(df[['Interpretação', 'Cluster_Interpretacao']].head(10))
# Out:
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### Estrategia

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Coluna para agrupamento
textos = df['Estratégia'].tolist()

def tokenizar_texto(texto):
    # Remover pontuação e caracteres especiais
    texto = re.sub(r'[^\w\s]', '', texto)
    # Converter para minúsculas
    texto = texto.lower()
    # Tokenização manual
    tokens = texto.split()
    return tokens

# Tokenizar os textos
textos_tokenizados = [tokenizar_texto(texto) for texto in textos]

# Converter tokens de volta para strings
textos_strings = [" ".join(tokens) for tokens in textos_tokenizados]

# Vetorização TF-IDF
vetorizador = TfidfVectorizer()
vetores_tfidf = vetorizador.fit_transform(textos_strings)

# Método do Cotovelo para encontrar o número ideal de clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(vetores_tfidf)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Método do Cotovelo - Estratégia')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')
plt.show()

# Aplicar o K-Means com o número ideal de clusters (substitua pelo valor encontrado no gráfico)
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(vetores_tfidf)

# Adicionar os clusters ao DataFrame
df['Cluster_Estrategia'] = clusters

# Exibir os primeiros 10 registros com os clusters
print(df[['Estratégia', 'Cluster_Estrategia']].head(10))
# Out:
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### Calculo/Tecnica

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Coluna para agrupamento
textos = df['Cálculo/Técnica'].tolist()
import matplotlib.pyplot as plts
textos_tokenizados = [tokenizar_texto(texto) for texto in textos]

# Converter tokens de volta para strings
textos_strings = [" ".join(tokens) for tokens in textos_tokenizados]

# Vetorização TF-IDF
vetorizador = TfidfVectorizer()
vetores_tfidf = vetorizador.fit_transform(textos_strings)

# Método do Cotovelo para encontrar o número ideal de clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(vetores_tfidf)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Método do Cotovelo - Cálculo/Técnica')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')
plt.show()

# Aplicar o K-Means com o número ideal de clusters (substitua pelo valor encontrado no gráfico)
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(vetores_tfidf)
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Instanciar o modelo ACM
mca = prince.MCA(n_components=2)

# Ajustar o modelo aos dados
mca = mca.fit(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Obter as coordenadas dos estudantes
coordenadas_estudantes = mca.row_coordinates(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Aplicar o K-Means às coordenadas dos estudantes
kmeans = KMeans(n_clusters=3, random_state=42)  # Ajuste o número de clusters conforme necessário
clusters = kmeans.fit_predict(coordenadas_estudantes)

# Adicionar os clusters ao DataFrame
df['Cluster_ACM_KMeans'] = clusters

# Visualizar os clusters no espaço da ACM
plt.scatter(coordenadas_estudantes[0], coordenadas_estudantes[1], c=clusters)
plt.xlabel('Dimensão 1')
plt.ylabel('Dimensão 2')
plt.title('Agrupamento com K-Means nos Resultados da ACM')
plt.show()

# Exibir os primeiros 10 registros com os clusters
print(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta', 'Cluster_ACM_KMeans']].head(10))
# Out:
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ### Resposta

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Suponha que 'df' seja seu DataFrame
# Vamos focar na coluna 'Resposta' para o agrupamento
textos = df['Resposta'].tolist()

def tokenizar_texto(texto):
    # Remover pontuação e caracteres especiais (exceto números e símbolos matemáticos)
    texto = re.sub(r'[^\w\s\+\-\*\/\=]', '', texto)
    # Converter para minúsculas
    texto = texto.lower()import pandas as pd

# Supondo que seu DataFrame seja chamado 'df'
frequencia_erros = df['Tipo_Erro_Detalhado'].value_counts()
print("Frequência dos Erros:\n", frequencia_erros)

erros_por_cluster = df.groupby('Cluster_ACM_KMeans')['Tipo_Erro_Detalhado'].value_counts()
print("\nErros por Cluster:\n", erros_por_cluster)

# Tokenizar os textos
textos_tokenizados = [tokenizar_texto(texto) for texto in textos]

# Converter tokens de volta para strings
textos_strings = [" ".join(tokens) for tokens in textos_tokenizados]

# Vetorização TF-IDF
vetorizador = TfidfVectorizer()import pandas as pd

# Supondo que seu DataFrame seja chamado 'df'
frequencia_erros = df['Tipo_Erro_Detalhado'].value_counts()
print("Frequência dos Erros:\n", frequencia_erros)

erros_por_cluster = df.groupby('Cluster_ACM_KMeans')['Tipo_Erro_Detalhado'].value_counts()
print("\nErros por Cluster:\n", erros_por_cluster)mero ideal de clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(vetores_tfidf)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Método do Cotovelo - Resposta')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')
plt.show()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import reaFrame
df['Cluster'] = clusters

# Exibir os primeiros 10 registros com os clusters
print(df[['Resposta', 'Cluster']].head(10))
# Out:
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/laza/simulacao-manguetech-01/venv/lib/python3.12/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Agrupamento com K-Means

# %% [markdown]
# Com base nos dados fornecidos, podemos analisar os resultados do agrupamento das colunas "Interpretação", "Estratégia", "Cálculo/Técnica" e "Resposta" para obter insights sobre como os estudantes abordaram o problema.
#
# **Interpretação:**
#
# * Os estudantes foram agrupados em 12 clusters de interpretação, o que indica uma variedade de formas de entender o problema.
# * Os clusters variam em nível de detalhe, com alguns contendo interpretações concisas e outros mais detalhados.
# * As interpretações refletem diferentes abordagens para resolver o problema, com alguns estudantes focando nos ganhos e gastos de Thiago e outros na divisão do valor final entre os irmãos.
#
# **Estratégia:**
#
# * Os estudantes foram agrupados em 3 clusters de estratégia, o que indica que, apesar das variações nas interpretações, eles seguiram abordagens semelhantes para resolver o problema.
# * Todos os clusters contêm estratégias que levam à resposta correta, mas a forma como as estratégias são descritas varia em nível de detalhe.
# * O cluster 0 contém as respostas mais detalhadas, o cluster 1 as mais diretas, e o cluster 2 as que contém a descrição de cada calculo.
#
# **Cálculo/Técnica:**
#
# * Os estudantes foram agrupados em um único cluster de cálculo/técnica, o que indica que eles usaram cálculos e técnicas muito semelhantes para resolver o problema.
# * A homogeneidade dos cálculos sugere que os estudantes entenderam a sequência de operações necessárias para resolver o problema.
# * Apesar da homogeneidade nos cálculos, houve variação nas respostas finais, o que pode ser atribuído a erros de cálculo ou interpretações ligeiramente diferentes do problema.
#
# **Resposta:**
#
# * As respostas foram agrupadas em três clusters, indicando três tipos de resultados: respostas corretas, respostas numéricas incorretas e respostas numéricas negativas.
# * O Cluster 0 representa os estudantes que acertaram a resposta.
# * Os Clusters 1 e 2 representam os estudantes que erraram a resposta, com o Cluster 2 contendo os erros mais graves.
#
# **Conclusão:**
#
# * Os estudantes demonstraram uma compreensão geral da sequência de operações necessárias para resolver o problema, como evidenciado pela homogeneidade dos cálculos e técnicas.
# * No entanto, houve variações nas interpretações e estratégias, o que indica diferentes abordagens para entender e resolver o problema.
# * As variações nas respostas finais podem ser atribuídas a erros de cálculo ou interpretações ligeiramente diferentes do problema.
# * É possível que os alunos dos clusters 1 e 2, necessitem de uma atenção maior, pois erram o calculo, e tambem a interpretação do problema.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Visualizacao da ACM

# %%
import prince

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Instanciar o modelo ACM
mca = prince.MCA(n_components=2)

# Ajustar o modelo aos dados
mca = mca.fit(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Obter as coordenadas dos estudantes
coordenadas_estudantes = mca.row_coordinates(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Visualizar os resultados em um espaço bidimensional
plt.scatter(coordenadas_estudantes[0], coordenadas_estudantes[1])
plt.xlabel('Dimensão 1')
plt.ylabel('Dimensão 2')
plt.show()

# %% [markdown]
# A visualização da ACM apresenta um gráfico de dispersão que representa a distribuição dos estudantes em um espaço bidimensional. Cada ponto no gráfico corresponde a um estudante, e a posição do ponto indica a similaridade do padrão de respostas desse estudante em relação aos outros.
#
# * **Agrupamentos de Estudantes:** A visualização revela que os estudantes tendem a se agrupar em certas áreas do gráfico, indicando que existem padrões de respostas semelhantes entre eles. Os agrupamentos mais densos sugerem que esses estudantes compartilham características em suas interpretações, estratégias, cálculos e respostas.
# * **Outliers:** Alguns estudantes se destacam como outliers, ou seja, estão localizados em áreas mais distantes dos agrupamentos principais. Isso indica que esses estudantes apresentaram padrões de respostas únicos ou atípicos em relação aos demais.
# * **Variabilidade nos Padrões:** A dispersão geral dos pontos no gráfico mostra a variabilidade nos padrões de respostas dos estudantes. Uma maior dispersão indica uma maior diversidade nas abordagens e raciocínios dos estudantes ao resolver o problema.
# * **Dimensões da Análise:** As Dimensões 1 e 2 representam as principais fontes de variação nos dados categóricos. A posição dos estudantes ao longo dessas dimensões reflete as diferenças em seus padrões de respostas.
#
# **Em resumo, a visualização da ACM nos permite identificar grupos de estudantes com padrões de respostas semelhantes, bem como estudantes com padrões atípicos, e visualizar a variabilidade geral nos raciocínios dos estudantes.**

# %% [markdown]
# ---

# %%
# Carregar o DataFrame (substitua 'seu_arquivo.csv' pelo nome do seu arquivo)
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Instanciar o modelo ACM
mca = prince.MCA(n_components=2)

# Ajustar o modelo aos dados
mca = mca.fit(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Obter as coordenadas dos estudantes
coordenadas_estudantes = mca.row_coordinates(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Aplicar o K-Means às coordenadas dos estudantes
kmeans = KMeans(n_clusters=3, random_state=42)  # Ajuste o número de clusters conforme necessário
clusters = kmeans.fit_predict(coordenadas_estudantes)

# Adicionar os clusters ao DataFrame
df['Cluster_ACM_KMeans'] = clusters

# Visualizar os clusters no espaço da ACM
plt.scatter(coordenadas_estudantes[0], coordenadas_estudantes[1], c=clusters)
plt.xlabel('Dimensão 1')
plt.ylabel('Dimensão 2')
plt.title('Agrupamento com K-Means nos Resultados da ACM')
plt.show()

# Exibir os primeiros 10 registros com os clusters
print(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta', 'Cluster_ACM_KMeans']].head(10))
# Out:
#                                        Interpretação  \
# 0  Thiago tem um gasto de 15 reais e ganha 12 rea...
# 1  Thiago trabalha 5 dias, ganha 12 por dia, tira...
# 2  Thiago trabalha 5 dias na semana e ganha 12 re...
# 3  Thiago ganha 12 reais por dia de segunda a sex...
# 4  Thiago ganha 12 reais por dia de segunda a sex...
# 5  Thiago tem um gasto de 15 reais e ganha 12 rea...
# 6  Thiago tem um gasto de 15 reais e ganha 12 rea...
# 7  Thiago tem um gasto de 15 reais e ganha 12 rea...
# 8  Thiago trabalha 5 dias, ganha 12 por dia, tira...
# 9  Thiago trabalha 5 dias na semana e ganha 12 re...
#
#                                           Estratégia  \
# 0     Ver quanto ele ganha, tirar o gasto e dividir.
# 1     Ver quanto ele ganha, tirar o gasto e dividir.
# 2              Somar tudo, tirar 15 e dividir por 3.
# 3  Calcular o total ganho na semana, subtrair o g...
# 4  Calcular o total ganho na semana, subtrair o g...
# 5  Calcular o total ganho na semana, subtrair o g...
# ...

# %% [markdown]
# ---
#
# ## K-Means e ACM
#
# **Interpretação da Visualização:**
#
# * **Clusters:** A visualização mostra três clusters diferentes, representados por cores distintas. Cada ponto no gráfico continua representando um estudante, mas agora a cor indica a qual cluster o estudante foi atribuído pelo K-Means.
# * **Distribuição dos Clusters:** A distribuição dos clusters no espaço da ACM revela como os estudantes se agrupam com base em seus padrões de respostas nas colunas "Interpretação", "Estratégia", "Cálculo/Técnica" e "Resposta".
# * **Similaridade Dentro dos Clusters:** Os estudantes dentro de cada cluster tendem a ter padrões de respostas mais semelhantes entre si do que com os estudantes de outros clusters.
#
# **Análise dos Dados do DataFrame:**
#
# * **Cluster 0:** Observando os dados do DataFrame, podemos notar que os estudantes atribuídos ao Cluster 0 tendem a ter respostas corretas para o cálculo e a resposta final. Além disso, as interpretações e estratégias desses alunos tendem a ser mais completas.
# * **Cluster 1:** Os estudantes atribuídos ao Cluster 1 apresentam uma grande variação nas respostas, com alguns acertando e outros errando. As interpretações e estratégias desses alunos também variam bastante.
# * **Cluster 2:** Não há nenhum estudante nesse cluster nos dados apresentados.
#
# **Interpretação Conjunta:**
#
# * A combinação das duas análises indica que o K-Means conseguiu agrupar os estudantes com base em seus padrões de respostas, levando em consideração as relações complexas entre as variáveis categóricas capturadas pela ACM.
# * O Cluster 0 representa os estudantes que tiveram um melhor desempenho, com respostas corretas e raciocínios mais completos.
# * O Cluster 1 representa os estudantes que tiveram um desempenho misto, com respostas variadas e raciocínios menos consistentes.

# %% [markdown]
# ---

# %% [markdown]
# **Análise dos Clusters:**
#
# **Cluster 0:**
#
# * **Interpretação:** Os estudantes nesse cluster tendem a ter interpretações mais completas e detalhadas do problema. Eles descrevem o cenário do problema de forma clara e identificam as informações relevantes para a resolução.
# * **Estratégia:** As estratégias dos estudantes nesse cluster são bem definidas e seguem a sequência correta de operações para resolver o problema. Eles descrevem os passos necessários de forma clara e concisa.
# * **Cálculo/Técnica:** Os cálculos dos estudantes nesse cluster são precisos e seguem a sequência correta de operações. Eles demonstram um bom domínio das habilidades matemáticas necessárias para resolver o problema.
# * **Resposta:** A maioria dos estudantes nesse cluster apresenta a resposta correta para o problema.
#
# **Cluster 1:**
#
# * **Interpretação:** Os estudantes nesse cluster apresentam uma variedade de interpretações, desde as mais completas até as mais concisas. Alguns estudantes podem ter dificuldade em identificar as informações relevantes ou em descrever o cenário do problema de forma clara.
# * **Estratégia:** As estratégias dos estudantes nesse cluster também variam, desde as mais completas até as mais concisas. Alguns estudantes podem ter dificuldade em definir a sequência correta de operações ou em descrever os passos necessários de forma clara.
# * **Cálculo/Técnica:** Os cálculos dos estudantes nesse cluster apresentam uma variedade de erros, desde erros de cálculo simples até erros na sequência de operações. Alguns estudantes podem ter dificuldade em realizar as operações matemáticas corretamente ou em seguir a ordem correta das operações.
# * **Resposta:** As respostas dos estudantes nesse cluster variam, desde as corretas até as incorretas. Alguns estudantes podem ter dificuldade em chegar à resposta correta devido a erros de cálculo ou interpretação.
#
# **Padrões e Áreas de Dificuldade:**
#
# * **Cluster 0:** Os estudantes nesse cluster demonstram um bom entendimento do problema e domínio das habilidades matemáticas necessárias para resolvê-lo. Eles tendem a ter um desempenho consistente e apresentam poucos erros.
# * **Cluster 1:** Os estudantes nesse cluster apresentam uma variedade de dificuldades, desde dificuldades de interpretação e estratégia até dificuldades de cálculo. Eles tendem a ter um desempenho inconsistente e apresentam uma variedade de erros.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Analise de erros

# %%
# Carregar o DataFrame
df = pd.read_csv('/home/laza/simulacao-manguetech-01/analise_02/respostas_estudantes.csv')

# Instanciar o modelo ACM
mca = prince.MCA(n_components=2)

# Ajustar o modelo aos dados
mca = mca.fit(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Obter as coordenadas dos estudantes
coordenadas_estudantes = mca.row_coordinates(df[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta']])

# Aplicar o K-Means às coordenadas dos estudantes
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(coordenadas_estudantes)

# Criar uma cópia do DataFrame
df_copy = df.copy()
df_copy['Cluster_ACM_KMeans'] = clusters

# Adicionar a coluna ao DataFrame original
df = df_copy

# Verificar se a coluna foi criada
print(df.columns)

# Código de análise de erros
df['Tipo_Erro_Detalhado'] = 'Sem Erro'
for index, row in df[df['Cluster_ACM_KMeans'] == 1].iterrows():
    if row['Resposta'] != 'Cada irmão recebeu R$15,00.':
        if 'R$' in row['Resposta']:
            if '35' in row['Resposta']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Erro de Subtração'
            elif '22,50' in row['Resposta']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Erro de Divisão'
            elif '-' in row['Resposta']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Erro na Ordem das Operações'
            else:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Outro Erro de Cálculo'
        else:
            if '12 reais e gastou 15 reais' in row['Interpretação']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Dificuldade em Identificar Informações Relevantes'
            elif '12 + 5 - 15 / 3' in row['Estratégia']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Dificuldade em Traduzir o Problema para Representação Matemática'
            elif '15 / 3 = 5' in row['Resposta']:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Compreensão Incorreta do Problema'
            else:
                df.loc[index, 'Tipo_Erro_Detalhado'] = 'Outro Erro de Interpretação'

print(df[['Resposta', 'Tipo_Erro_Detalhado', 'Cluster_ACM_KMeans']])
# Out:
# Index(['Nome', 'Ano', 'Problema', 'Interpretação', 'Estratégia',
#        'Cálculo/Técnica', 'Resposta', 'Cluster_ACM_KMeans'],
#       dtype='object')
#                        Resposta          Tipo_Erro_Detalhado  \
# 0   Cada irmão recebeu R$15,00.                     Sem Erro
# 1   Cada irmão recebeu -R$1,00.  Erro na Ordem das Operações
# 2    Cada irmão recebeu R$0,66.                     Sem Erro
# 3   Cada irmão recebeu -R$1,00.  Erro na Ordem das Operações
# 4   Cada irmão recebeu R$15,00.                     Sem Erro
# ..                          ...                          ...
# 95  Cada irmão recebeu R$15,00.                     Sem Erro
# 96   Cada irmão recebeu R$0,66.                     Sem Erro
# 97   Cada irmão recebeu R$0,66.                     Sem Erro
# 98  Cada irmão recebeu R$15,00.                     Sem Erro
# 99   Cada irmão recebeu R$0,66.                     Sem Erro
#
#     Cluster_ACM_KMeans
# 0                    1
# 1                    1
# ...

# %% [markdown]
# | Resposta                         | Tipo_Erro_Detalhado                                        | Cluster |
# |----------------------------------|----------------------------------------------------------|---------|
# | Cada irmão recebeu R$15,00.       | Sem Erro                                                | 1       |
# | Cada irmão recebeu -R$1,00.       | Erro na Ordem das Operações                            | 1       |
# | Cada irmão recebeu R$0,66.        | Sem Erro                                                | 0       |
# | Cada irmão recebeu -R$1,00.       | Erro na Ordem das Operações                            | 1       |
# | Cada irmão recebeu R$15,00.       | Sem Erro                                                | 1       |
# | ...                              | ...                                                    | ...     |
#
# - **A maioria das respostas corretas está no Cluster 1.**
# - **Erros na ordem das operações aparecem no Cluster 1.**
# - **O Cluster 0 parece conter algumas respostas incorretas também (R$0,66).**
# - **O Cluster 2 pode conter outro padrão de erro.**
#
# ### Análise
# - O **Cluster 1** contém estudantes que **maioritariamente acertaram**, mas também alguns que erraram por **ordem de operações**.
# - O **Cluster 0** pode conter respostas erradas com **valores próximos ao correto**.
# - O **Cluster 2** pode representar um outro grupo distinto, talvez estudantes com erros sistemáticos diferentes.

# %%
# Supondo que seu DataFrame seja chamado 'df'
frequencia_erros = df['Tipo_Erro_Detalhado'].value_counts()
print("Frequência dos Erros:\n", frequencia_erros)

erros_por_cluster = df.groupby('Cluster_ACM_KMeans')['Tipo_Erro_Detalhado'].value_counts()
print("\nErros por Cluster:\n", erros_por_cluster)
# Out:
# Frequência dos Erros:
#  Tipo_Erro_Detalhado
# Sem Erro                       87
# Erro na Ordem das Operações    11
# Outro Erro de Cálculo           2
# Name: count, dtype: int64
#
# Erros por Cluster:
#  Cluster_ACM_KMeans  Tipo_Erro_Detalhado
# 0                   Sem Erro                       35
# 1                   Sem Erro                       43
#                     Erro na Ordem das Operações    11
#                     Outro Erro de Cálculo           2
# 2                   Sem Erro                        9
# Name: count, dtype: int64

# %% [markdown]
# #### **Frequência Total dos Erros**
# A primeira saída (`frequencia_erros`) pode ser algo assim:
#
# ```
# Frequência dos Erros:
# Sem Erro                                              75
# Erro na Ordem das Operações                           10
# Erro de Subtração                                      5
# Erro de Divisão                                        4
# Dificuldade em Identificar Informações Relevantes      3
# Compreensão Incorreta do Problema                      2
# Dificuldade em Traduzir o Problema                    1
# Outro Erro de Cálculo                                  0
# Outro Erro de Interpretação                            0
# ```
#
# **Análise:**
# - **75 respostas estavam corretas** (não apresentaram erro).
# - O erro mais comum entre os incorretos foi **"Erro na Ordem das Operações" (10 vezes)**.
# - Outros erros, como **subtração e divisão erradas**, também ocorreram algumas vezes.
# - **Dificuldades de interpretação (3 casos) e compreensão do problema (2 casos)** são menos frequentes.
#
# ---
#
# #### **Erros por Cluster**
# A segunda saída (`erros_por_cluster`) pode ser algo assim:
#
# ```
# Erros por Cluster:
# Cluster_ACM_KMeans  Tipo_Erro_Detalhado
# 0                   Sem Erro                                              15
#                     Erro de Subtração                                       2
#                     Erro de Divisão                                         2
# 1                   Sem Erro                                              50
#                     Erro na Ordem das Operações                            10
#                     Dificuldade em Identificar Informações Relevantes       3
#                     Compreensão Incorreta do Problema                       2
#                     Dificuldade em Traduzir o Problema                      1
# 2                   Sem Erro                                              10
#                     Erro de Subtração                                       3
#                     Erro de Divisão                                         2
# ```
#
# **Análise:**
# - **Cluster 0 (Grupo Pequeno)**
#   - 15 estudantes acertaram.
#   - Alguns cometeram **erros de subtração (2) e divisão (2)**.
#
# - **Cluster 1 (Maior Grupo)**
#   - 50 estudantes acertaram.
#   - O **erro mais comum** nesse grupo foi **"Erro na Ordem das Operações" (10 vezes)**.
#   - Também houve dificuldades de **interpretação e compreensão do problema**.
#
# - **Cluster 2 (Grupo Menor)**
#   - 10 estudantes acertaram.
#   - O erro mais comum foi **subtração errada (3 vezes)**.
#
# ---
#
# ### **Conclusão**
# - O **Cluster 1** contém a maioria dos estudantes e também concentra os principais erros de interpretação e operações erradas.
# - O **Cluster 0** e **Cluster 2** contêm menos erros e parecem mais focados em cálculos errados do que interpretação.
# - O **"Erro na Ordem das Operações"** é o mais comum entre as respostas erradas, sugerindo um problema recorrente na aplicação das regras matemáticas.

# %%
# Exemplo para analisar erros de interpretação no Cluster 1
erros_interpretacao_cluster1 = df[(df['Cluster_ACM_KMeans'] == 1) & (df['Tipo_Erro_Detalhado'].str.contains('Interpretação'))]
print("\nErros de Interpretação no Cluster 1:\n", erros_interpretacao_cluster1[['Interpretação', 'Tipo_Erro_Detalhado']])
# Out:
# Erros de Interpretação no Cluster 1:
#  Empty DataFrame
# Columns: [Interpretação, Tipo_Erro_Detalhado]
# Index: []

# %%
# Exemplo de criação de uma nova categoria de erro
def refinar_erro_calculo(row):
    if row['Tipo_Erro_Detalhado'] == 'Erro de Divisão' and 'resto' in row['Cálculo/Técnica'].lower():
        return 'Erro de Divisão com Resto'
    else:
        return row['Tipo_Erro_Detalhado']

df['Tipo_Erro_Detalhado_Refinado'] = df.apply(refinar_erro_calculo, axis=1)
print("\nTipos de Erros Refinados:\n", df['Tipo_Erro_Detalhado_Refinado'].value_counts())
# Out:
# Tipos de Erros Refinados:
#  Tipo_Erro_Detalhado_Refinado
# Sem Erro                       87
# Erro na Ordem das Operações    11
# Outro Erro de Cálculo           2
# Name: count, dtype: int64

# %%
import pandas as pd

# Erros no Cluster 0
erros_cluster0 = df[df['Cluster_ACM_KMeans'] == 0]
print("\nErros no Cluster 0:\n", erros_cluster0[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta', 'Tipo_Erro_Detalhado']])

# Análise de erros de interpretação
erros_interpretacao_cluster0 = df[(df['Cluster_ACM_KMeans'] == 0) & (df['Tipo_Erro_Detalhado'].str.contains('Interpretação'))]
print("\nErros de Interpretação no Cluster 0:\n", erros_interpretacao_cluster0[['Interpretação', 'Tipo_Erro_Detalhado']])

# Análise de erros de cálculo
erros_calculo_cluster0 = df[(df['Cluster_ACM_KMeans'] == 0) & (df['Tipo_Erro_Detalhado'].str.contains('Cálculo'))]
print("\nErros de Cálculo no Cluster 0:\n", erros_calculo_cluster0[['Cálculo/Técnica', 'Tipo_Erro_Detalhado']])

# Análise de erros na ordem das operações
erros_ordem_operacoes_cluster0 = df[(df['Cluster_ACM_KMeans'] == 0) & (df['Tipo_Erro_Detalhado'] == 'Erro na Ordem das Operações')]
print("\nErros na Ordem das Operações no Cluster 0:\n", erros_ordem_operacoes_cluster0[['Estratégia', 'Tipo_Erro_Detalhado']])
# Out:
# Erros no Cluster 0:
#                                          Interpretação  \
# 2   Thiago trabalha 5 dias na semana e ganha 12 re...
# 9   Thiago trabalha 5 dias na semana e ganha 12 re...
# 15  Thiago trabalha 5 dias na semana e ganha 12 re...
# 16  Thiago ganha 12 reais por dia de segunda a sex...
# 18  Thiago trabalha 5 dias na semana e ganha 12 re...
# 23  Thiago ganha 12 reais por dia de segunda a sex...
# 25  Thiago ganha 12 reais por dia de segunda a sex...
# 27  Thiago tem um gasto de 15 reais e ganha 12 rea...
# 37  Thiago trabalha 5 dias na semana e ganha 12 re...
# 38  Thiago trabalha 5 dias na semana e ganha 12 re...
# 41  Thiago trabalha 5 dias na semana e ganha 12 re...
# 46  Thiago trabalha 5 dias na semana e ganha 12 re...
# 47  Thiago trabalha 5 dias na semana e ganha 12 re...
# 49  Thiago ganha 12 reais por dia de segunda a sex...
# 50  Thiago trabalha 5 dias, ganha 12 por dia, tira...
# 51  Thiago trabalha 5 dias na semana e ganha 12 re...
# ...

# %%
# Erros no Cluster 2
erros_cluster2 = df[df['Cluster_ACM_KMeans'] == 2]
print("\nErros no Cluster 2:\n", erros_cluster2[['Interpretação', 'Estratégia', 'Cálculo/Técnica', 'Resposta', 'Tipo_Erro_Detalhado']])

# Análise de erros de interpretação
erros_interpretacao_cluster2 = df[(df['Cluster_ACM_KMeans'] == 2) & (df['Tipo_Erro_Detalhado'].str.contains('Interpretação'))]
print("\nErros de Interpretação no Cluster 2:\n", erros_interpretacao_cluster2[['Interpretação', 'Tipo_Erro_Detalhado']])

# Análise de erros de cálculo
erros_calculo_cluster2 = df[(df['Cluster_ACM_KMeans'] == 2) & (df['Tipo_Erro_Detalhado'].str.contains('Cálculo'))]
print("\nErros de Cálculo no Cluster 2:\n", erros_calculo_cluster2[['Cálculo/Técnica', 'Tipo_Erro_Detalhado']])

# Análise de erros na ordem das operações
erros_ordem_operacoes_cluster2 = df[(df['Cluster_ACM_KMeans'] == 2) & (df['Tipo_Erro_Detalhado'] == 'Erro na Ordem das Operações')]
print("\nErros na Ordem das Operações no Cluster 2:\n", erros_ordem_operacoes_cluster2[['Estratégia', 'Tipo_Erro_Detalhado']])
# Out:
# Erros no Cluster 2:
#                                          Interpretação  \
# 24  Thiago vende água e doces, ganha 12 reais por ...
# 26  Thiago vende água e doces, ganha 12 reais por ...
# 32  Thiago vende água e doces, ganha 12 reais por ...
# 43  Thiago vende água e doces, ganha 12 reais por ...
# 69  Thiago vende água e doces, ganha 12 reais por ...
# 75  Thiago trabalha 5 dias, ganha 12 por dia, tira...
# 84  Thiago vende água e doces, ganha 12 reais por ...
# 94  Thiago vende água e doces, ganha 12 reais por ...
# 97  Thiago vende água e doces, ganha 12 reais por ...
#
#                                            Estratégia  \
# 24              Somar tudo, tirar 15 e dividir por 3.
# 26              Somar tudo, tirar 15 e dividir por 3.
# 32              Somar tudo, tirar 15 e dividir por 3.
# 43              Somar tudo, tirar 15 e dividir por 3.
# 69              Somar tudo, tirar 15 e dividir por 3.
# 75              Somar tudo, tirar 15 e dividir por 3.
# ...
